# %%
testdata = """mask = XXXXXXXXXXXXXXXXXXXXXXXXXXXXX1XXXX0X
mem[8] = 11
mem[7] = 101
mem[8] = 0""".splitlines()

# %%
print(2**35 - 1)
# Out:
# 34359738367

# %%
def parse_mask(mask):
    positive, negative = (0, 2**37 - 1)
    mask = mask[::-1]
    for i in range(len(mask)):
        if mask[i] == '1':
            positive += 2**i
        elif mask[i] == '0':
            negative -= 2**i
    return positive, negative

# %%
print(parse_mask('XXXXXXXXXXXXXXXXXXXXXXXXXXXXX1XXXX0X'))
print(7 & 34359738365)
# Out:
# (64, 137438953469)
# 5

# %%
def parse_instruction(line):
    a, b = line.split(' = ')
    print(line)
    if a == 'mask':
        return a, parse_mask(b)
    elif a[0:3] == 'mem':
        return 'mem', int(a[4:-1]), int(b)

# %%
print(parse_instruction('mask = XXXXXXXXXXXXXXXXXXXXXXXXXXXXX1XXXX0X'))
print(parse_instruction('mem[8] = 11'))
print(parse_instruction('mem[7] = 101'))
# Out:
# mask = XXXXXXXXXXXXXXXXXXXXXXXXXXXXX1XXXX0X
# ('mask', (64, 137438953469))
# mem[8] = 11
# ('mem', 8, 11)
# mem[7] = 101
# ('mem', 7, 101)

# %%
a = 'mem[8]'
print(a[4:-1])
# Out:
# 8

# %%
def set_mask(p_n):
    global MASK_P
    global MASK_N
    MASK_P, MASK_N = p_n[0]
    print(f'Set masks to {MASK_P}, {MASK_N}')

def set_mem(addr_arg):
    addr, arg = (addr_arg[0], addr_arg[1])
    print(f'Set memory {addr} to {(arg | MASK_P ) & MASK_N} (originally {arg}, with masks {MASK_P} and {MASK_N}')
    MEM[addr] = (arg | MASK_P ) & MASK_N

opcodes = {
    'mask': set_mask,
    'mem': set_mem,
}

# %%
def execute(instructions):
    for instr in [parse_instruction(instruction) for instruction in instructions]:
        # print(f'executing: {instr}')
        opcodes[instr[0]](instr[1:])

# %%
MASK_P, MASK_N = (0, 2**36 - 1)
MEM = dict()

execute(testdata)
print(MEM, MASK_P, MASK_N)
print(f'Sum of memory: {sum([val for val in MEM.values()])}')
# Out:
# mask = XXXXXXXXXXXXXXXXXXXXXXXXXXXXX1XXXX0X
# mem[8] = 11
# mem[7] = 101
# mem[8] = 0
# Set masks to 64, 137438953469
# Set memory 8 to 73 (originally 11, with masks 64 and 137438953469
# Set memory 7 to 101 (originally 101, with masks 64 and 137438953469
# Set memory 8 to 64 (originally 0, with masks 64 and 137438953469
# {8: 64, 7: 101} 64 137438953469
# Sum of memory: 165

# %%
MASK_P, MASK_N = (0, 2**36 - 1)
MEM = dict()

with open('input', 'r') as inp:
    inputdata = [line.strip() for line in inp.readlines()]

execute(inputdata)
print(MEM, MASK_P, MASK_N)
print(f'Sum of memory: {sum([val for val in MEM.values()])}')
# Out:
# 250 to 57351410336 (originally 47809475, with masks 57317855904 and 128218387112
# Set memory 2450 to 57351410336 (originally 116013203, with masks 57317855904 and 128218387112
# Set memory 49776 to 57317855904 (originally 393349, with masks 57317855904 and 128218387112
# Set masks to 57314760386, 128185923274
# Set memory 53450 to 57314768586 (originally 656535467, with masks 57314760386 and 128185923274
# Set memory 6408 to 57314760386 (originally 21122, with masks 57314760386 and 128185923274
# Set memory 40154 to 57314768578 (originally 1342486, with masks 57314760386 and 128185923274
# Set masks to 58060117039, 127065855087
# Set memory 4324 to 58060117039 (originally 686588689, with masks 58060117039 and 127065855087
# Set memory 64022 to 58061165679 (originally 1565401, with masks 58060117039 and 127065855087
# Set memory 35893 to 58060117039 (originally 9127, with masks 58060117039 and 127065855087
# Set memory 63924 to 58060117103 (originally 5346, with masks 58060117039 and 127065855087
# Set masks to 23894552327, 128270069655
# Set memory 18336 to 23915785991 (originally 33319783, with masks 23894552327 and 128270069655
# Set memory 9347 to 23898746759 (originally 7493509, with masks 23894552327 and 128270069655
# Set memory 6227 to 23894552343 (originally 1816, with masks 23894552327 and 128270069655
# Set memory 31665 to 23899008775 (originally 5514016, with masks 23894552327 and 128270069655
# Set memory 51408 to 23894552327 (originally 4879, with masks 23894552327 and 128270069655
# Set memory 53450 to 23894552471 (originally 114937, with masks 23894552327 and 128270069655
# Set masks to 21475459864, 91003409368
# Set memory 46925 to 21475459928 (originally 103, with masks 21475459864 and 91003409368
# Set memory 57394 to 21475463960 (originally 965124, with masks 21475459864 and 91003409368
# Set memory 15985 to 21475480472 (originally 980924, with masks 21475459864 and 91003409368
# Set memory 52270 to 21475459992 (originally 110464, with masks 21475459864 and 91003409368
# Set memory 15394 to 21475460056 (originally 1276, with masks 21475459864 and 91003409368
# Set masks to 1087701003, 121515095563
# Set memory 13230 to 1087705611 (originally 1399497, with masks 1087701003 and 121515095563
# Set memory 64578 to 1087702027 (originally 3309, with masks 1087701003 and 121515095563
# Set memory 25149 to 1087706635 (originally 7933, with masks 1087701003 and 121515095563
# Set masks to 22963355889, 91699780091
# Set memory 16284 to 22980165875 (originally 27584023, with masks 22963355889 and 91699780091
# Set memory 46579 to 22980135419 (originally 360009595, with masks 22963355889 and 91699780091
# Set memory 30484 to 22963491313 (originally 677717, with masks 22963355889 and 91699780091
# Set memory 11059 to 22980135161 (originally 52513896, with masks 22963355889 and 91699780091
# Set memory 38700 to 22963355899 (originally 683, with masks 22963355889 and 91699780091
# Set masks to 58253928455, 127532005399
# Set memory 16164 to 58253928471 (originally 177, with masks 58253928455 and 127532005399
# Set memory 8961 to 58258778135 (originally 6185342, with masks 58253928455 and 127532005399
# Set memory 53026 to 58258647047 (originally 72900939, with masks 58253928455 and 127532005399
# Set masks to 41282389240, 136851707132
# Set memory 59825 to 41282393336 (originally 37712, with masks 41282389240 and 136851707132
# Set memory 42879 to 41282389244 (originally 746543, with masks 41282389240 and 136851707132
# Set memory 16391 to 41284486392 (originally 54454690, with masks 41282389240 and 136851707132
# Set memory 43036 to 41282389244 (originally 346868, with masks 41282389240 and 136851707132
# Set memory 25030 to 41282393336 (originally 38931, with masks 41282389240 and 136851707132
# Set memory 5215 to 41282389244 (originally 890634260, with masks 41282389240 and 136851707132
# Set masks to 59066008356, 128053931836
# Set memory 19490 to 59066009404 (originally 5726, with masks 59066008356 and 128053931836
# Set memory 17000 to 59066008356 (originally 16738, with masks 59066008356 and 128053931836
# Set memory 61693 to 59066011428 (originally 7616, with masks 59066008356 and 128053931836
# Set memory 2295 to 59066009404 (originally 1627, with masks 59066008356 and 128053931836
# Set memory 44236 to 59066008364 (originally 269, with masks 59066008356 and 128053931836
# Set memory 4389 to 59066017588 (originally 1030099, with masks 59066008356 and 128053931836
# Set memory 11170 to 59066008356 (originally 4961, with masks 59066008356 and 128053931836
# Set masks to 20843304066, 93874797731
# Set memory 27835 to 20843314338 (originally 16102, with masks 20843304066 and 93874797731
# Set memory 12301 to 20843306115 (originally 8157, with masks 20843304066 and 93874797731
# Set memory 38801 to 20860091523 (originally 32685079, with masks 20843304066 and 93874797731
# Set masks to 24985037703, 128064519079
# Set memory 64949 to 24985041799 (originally 21205, with masks 24985037703 and 128064519079
# Set memory 56917 to 24985303943 (originally 416029376, with masks 24985037703 and 128064519079
# Set memory 50979 to 24985303975 (originally 2487904, with masks 24985037703 and 128064519079
# Set memory 64022 to 24985037735 (originally 2045, with masks 24985037703 and 128064519079
# Set memory 13313 to 24985299847 (originally 804618, with masks 24985037703 and 128064519079
# Set memory 55628 to 24985037735 (originally 17126, with masks 24985037703 and 128064519079
# Set masks to 22965510148, 126061638869
# Set memory 39628 to 22965510292 (originally 924, with masks 22965510148 and 126061638869
# Set memory 39127 to 22965515413 (originally 3978399, with masks 22965510148 and 126061638869
# Set memory 36741 to 22965510213 (originally 1917293, with masks 22965510148 and 126061638869
# Set memory 62950 to 22965514325 (originally 6997, with masks 22965510148 and 126061638869
# Set masks to 31498807108, 100218552293
# Set memory 20491 to 31498807268 (originally 500, with masks 31498807108 and 100218552293
# Set memory 36269 to 31498811236 (originally 22639420, with masks 31498807108 and 100218552293
# Set memory 44179 to 31498807237 (originally 725, with masks 31498807108 and 100218552293
# Set memory 48503 to 31499071332 (originally 520056, with masks 31498807108 and 100218552293
# Set memory 7514 to 31498809285 (originally 28103, with masks 31498807108 and 100218552293
# Set memory 54438 to 31499069284 (originally 410686, with masks 31498807108 and 100218552293
# Set masks to 21618732061, 93832588319
# Set memory 45749 to 21618732063 (originally 494350, with masks 21618732061 and 93832588319
# Set memory 44246 to 21618732063 (originally 3578, with masks 21618732061 and 93832588319
# Set memory 15900 to 21618732063 (originally 1654, with masks 21618732061 and 93832588319
# Set memory 32209 to 21618732061 (originally 218393668, with masks 21618732061 and 93832588319
# Set memory 30484 to 21619256349 (originally 213583441, with masks 21618732061 and 93832588319
# Set memory 25092 to 21618732063 (originally 55738, with masks 21618732061 and 93832588319
# Set masks to 17589358622, 87383954398
# Set memory 39783 to 17589359326 (originally 25297, with masks 17589358622 and 87383954398
# Set memory 60998 to 17589358878 (originally 35841298, with masks 17589358622 and 87383954398
# Set memory 54570 to 17589358878 (originally 2329, with masks 17589358622 and 87383954398
# Set memory 41435 to 17590669854 (originally 43307534, with masks 17589358622 and 87383954398
# Set memory 55264 to 17589687262 (originally 375757, with masks 17589358622 and 87383954398
# Set memory 63681 to 17589424414 (originally 112957, with masks 17589358622 and 87383954398
# Set masks to 56915238929, 126045758265
# Set memory 55707 to 56923627569 (originally 16304353, with masks 56915238929 and 126045758265
# Set memory 14995 to 56915238929 (originally 11351, with masks 56915238929 and 126045758265
# Set memory 12346 to 57057845529 (originally 746754510, with masks 56915238929 and 126045758265
# Set memory 11376 to 56915239185 (originally 339, with masks 56915238929 and 126045758265
# Set memory 2762 to 56915239481 (originally 51886, with masks 56915238929 and 126045758265
# Set memory 26983 to 56915239441 (originally 4316816, with masks 56915238929 and 126045758265
# Set masks to 18661217468, 89531324092
# Set memory 25172 to 18664363196 (originally 183861621, with masks 18661217468 and 89531324092
# Set memory 5742 to 18663315132 (originally 14878506, with masks 18661217468 and 89531324092
# Set masks to 18661081686, 126045892438
# Set memory 51566 to 18661083990 (originally 2828, with masks 18661081686 and 126045892438
# Set memory 18567 to 18661081942 (originally 265, with masks 18661081686 and 126045892438
# Set memory 16314 to 18661221974 (originally 423578, with masks 18661081686 and 126045892438
# Set memory 5215 to 18661081686 (originally 239, with masks 18661081686 and 126045892438
# Set memory 42065 to 18663311190 (originally 2230191, with masks 18661081686 and 126045892438
# Set masks to 19603185943, 93775849943
# Set memory 10367 to 19603186135 (originally 9431, with masks 19603185943 and 93775849943
# Set memory 23257 to 19603186007 (originally 10057, with masks 19603185943 and 93775849943
# Set memory 37558 to 19603185943 (originally 789, with masks 19603185943 and 93775849943
# Set memory 2683 to 19670819159 (originally 83395426, with masks 19603185943 and 93775849943
# Set memory 19984 to 19603775831 (originally 148832616, with masks 19603185943 and 93775849943
# Set masks to 53085176392, 126120591995
# Set memory 47509 to 53085176426 (originally 998, with masks 53085176392 and 126120591995
# Set memory 41953 to 53101953659 (originally 20146419, with masks 53085176392 and 126120591995
# Set memory 44664 to 53085176426 (originally 302148902, with masks 53085176392 and 126120591995
# Set memory 63696 to 53085176408 (originally 1160792, with masks 53085176392 and 126120591995
# Set memory 17933 to 53106147913 (originally 98120645, with masks 53085176392 and 126120591995
# Set memory 49199 to 53085176409 (originally 931033, with masks 53085176392 and 126120591995
