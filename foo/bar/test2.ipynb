# %%
import sys
sys.path.append('../../')
import common

properties = common.load_properties('../../config.ini')
if 'USER_SESSION_ID' in properties.keys():
    USER_SESSION_ID = properties['USER_SESSION_ID']

# %%
foo = dict()
foo['bar'] = 'car'
if foo:
    print('true')
else:
    print('false')
# Out:
# true
