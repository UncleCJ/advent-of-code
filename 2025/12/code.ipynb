# %% [markdown]
# # Day 12: Christmas Tree Farm
#
# [*Advent of Code 2025 day 12*](https://adventofcode.com/2025/day/12) and [*solution megathread*](https://redd.it/)
#
# [![nbviewer](https://raw.githubusercontent.com/jupyter/design/master/logos/Badges/nbviewer_badge.svg)](https://nbviewer.jupyter.org/github/UncleCJ/advent-of-code/blob/cj/2025/12/code.ipynb) [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/UncleCJ/advent-of-code/cj?filepath=2025%2F12%2Fcode.ipynb)

# %%
from IPython.display import HTML
import sys
sys.path.append('../../')


# %load_ext nb_mypy
# %nb_mypy On

# %%
import common


downloaded = common.refresh()
# %store downloaded >downloaded

# %load_ext pycodestyle_magic
# %pycodestyle_on
# Out:
# Writing 'downloaded' (dict) to file 'downloaded'.

# %%
from IPython.display import HTML

HTML(downloaded['part1'])
# Out:
# <h2>--- Day 12: Christmas Tree Farm ---</h2><p>You're almost out of time, but there can't be much left to decorate. Although there are no stairs, elevators, escalators, tunnels, chutes, teleporters, firepoles, or conduits here that would take you deeper into the North Pole base, there <em>is</em> a ventilation duct. You jump in.</p>
# <p>After bumping around for a few minutes, you emerge into a large, well-lit cavern full of Christmas trees!</p>
# <p>There are a few Elves here frantically decorating before the deadline. They think they'll be able to finish most of the work, but the one thing they're worried about is the <em>presents</em> for all the young Elves that live here at the North Pole. It's an ancient tradition to put the presents under the trees, but the Elves are worried they won't <em>fit</em>.</p>
# ...

# %%
part1_example_input = '''0:
###
##.
##.

1:
###
##.
.##

2:
.##
###
##.

3:
##.
###
##.

4:
###
#..
###

5:
###
.#.
###

4x4: 0 0 0 0 2 0
12x5: 1 0 1 0 2 2
12x5: 1 0 1 0 3 2'''

inputdata = downloaded['input']

# %%
from typing import Iterable

type DevicesOutputs = dict[str, tuple[str, ...]]

def parse_input(lines: Iterable[str]) -> DevicesOutputs:
    results: DevicesOutputs = dict()
    for line in lines:
        tokens = list(line.split(' '))
        device = tokens[0][:-1]
        outputs = tuple(tokens[1:])
        results[device] = outputs
    return results

# parsed_input = parse_input(part1_example_input.splitlines())
parsed_input = parse_input(inputdata.splitlines())

# %%
HTML(downloaded['part1_footer'])
# Out:
# <p>To begin, <a href="10/input" target="_blank">get your puzzle input</a>.</p>
# <form method="post" action="10/answer"><input type="hidden" name="level" value="1"/><p>Answer: <input type="text" name="answer" autocomplete="off"/> <input type="submit" value="[Submit]"/></p></form>
# <p>You can also <span class="share">[Share<span class="share-content">on
#   <a href="https://bsky.app/intent/compose?text=%22Factory%22+%2D+Day+10+%2D+Advent+of+Code+2025+%23AdventOfCode+https%3A%2F%2Fadventofcode%2Ecom%2F2025%2Fday%2F10" target="_blank">Bluesky</a>
#   <a href="https://twitter.com/intent/tweet?text=%22Factory%22+%2D+Day+10+%2D+Advent+of+Code+2025&amp;url=https%3A%2F%2Fadventofcode%2Ecom%2F2025%2Fday%2F10&amp;related=ericwastl&amp;hashtags=AdventOfCode" target="_blank">Twitter</a>
# ...

# %%
# HTML(downloaded['part2'])

# %%
# HTML(downloaded['part2_footer'])
