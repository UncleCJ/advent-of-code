# %% [markdown]
# # Day 4: The Ideal Stocking Stuffer
#
# [*Advent of Code 2015 day 4*](https://adventofcode.com/2015/day/4) and [*solution megathread*](https://www.reddit.com/3vdn8a)
#
# [![nbviewer](https://raw.githubusercontent.com/jupyter/design/master/logos/Badges/nbviewer_badge.svg)](https://nbviewer.jupyter.org/github/UncleCJ/advent-of-code/blob/cj/2015/03/code.ipynb) [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/UncleCJ/advent-of-code/rework?filepath=2015%2F04%2Fcode.ipynb)

# %%
from IPython.display import HTML
import sys

sys.path.append('../../')
import common

# %%
downloaded = common.refresh()
# %store downloaded >downloaded
# Out:
# Writing 'downloaded' (dict) to file 'downloaded'.

# %%
HTML(downloaded['part1'])
# Out:
# <article class="day-desc"><h2>--- Day 4: The Ideal Stocking Stuffer ---</h2><p>Santa needs help <a href="https://en.wikipedia.org/wiki/Bitcoin#Mining">mining</a> some <span title="Hey, mined your own business!">AdventCoins</span> (very similar to <a href="https://en.wikipedia.org/wiki/Bitcoin">bitcoins</a>) to use as gifts for all the economically forward-thinking little girls and boys.</p>
# <p>To do this, he needs to find <a href="https://en.wikipedia.org/wiki/MD5">MD5</a> hashes which, in <a href="https://en.wikipedia.org/wiki/Hexadecimal">hexadecimal</a>, start with at least <em>five zeroes</em>.  The input to the MD5 hash is some secret key (your puzzle input, given below) followed by a number in decimal. To mine AdventCoins, you must find Santa the lowest positive number (no leading zeroes: <code>1</code>, <code>2</code>, <code>3</code>, ...) that produces such a hash.</p>
# <p>For example:</p>
# <ul>
# ...

# %%
# testdata = [('>', 2),
#             ('^>v<', 4),
#             ('^v^v^v^v^v', 2)]
             
# inputdata = downloaded['input']

# %%
# downloaded['input'][1:5]

# %%
# def my_part1_solution(data):

# %%
# for d, r in testdata:
#      assert(my_part1_solution(d) == r)
#      print('{} asserted to evaluate to {}'.format(d, r))

# %%
# print(my_part1_solution(inputdata))

# %%
HTML(downloaded['part1_footer'])
# Out:
# <p>Your puzzle input is <code class="puzzle-input">yzbqklnj</code>.</p>
# <form method="post" action="4/answer"><input type="hidden" name="level" value="1"/><p>Answer: <input type="text" name="answer" autocomplete="off"/> <input type="submit" value="[Submit]"/></p></form>
# <p>You can also <span class="share">[Share<span class="share-content">on
#   <a href="https://twitter.com/intent/tweet?text=%22The+Ideal+Stocking+Stuffer%22+%2D+Day+4+%2D+Advent+of+Code+2015&amp;url=https%3A%2F%2Fadventofcode%2Ecom%2F2015%2Fday%2F4&amp;related=ericwastl&amp;hashtags=AdventOfCode" target="_blank">Twitter</a>
# ...

# %%
# HTML(downloaded['part2'])

# %%
# def my_part2_solution(data):

# %%
# testdata2 = [('^v', 3),
#             ('^>v<', 3),
#             ('^v^v^v^v^v', 11)]

# for d, r in testdata2:
#      assert(my_part2_solution(d) == r)
#      print('{} asserted to evaluate to {}'.format(d, r))

# %%
# print(my_part2_solution(inputdata))

# %%
# HTML(downloaded['part2_footer'])
