# %% [markdown]
# # Day 2: Password Philosophy
#
# [*Advent of Code day 2 - 2020-12-02*](https://adventofcode.com/2020/day/2) and [*solution megathread*](https://www.reddit.com/r/adventofcode/comments/k52psu/2020_day_02_solutions/)
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/UncleCJ/advent-of-code/cj?filepath=day-02%2Fday-02.ipynb)
#
# Your flight departs in a few days from the coastal airport; the easiest way down to the coast from here is via [toboggan](https://en.wikipedia.org/wiki/Toboggan).
#
# The shopkeeper at the North Pole Toboggan Rental Shop is having a bad day. "Something's wrong with our computers; we can't log in!" You ask if you can take a look.

# %% [markdown]
# ## Part 1
#
# Their password database seems to be a little corrupted: some of the passwords wouldn't have been allowed by the Official Toboggan Corporate Policy that was in effect when they were chosen.
#
# To try to debug the problem, they have created a list (your puzzle input) of *passwords* (according to the corrupted database) and *the corporate policy when that password was set.*
#
# For example, suppose you have the following list:
#
# ```
# 1-3 a: abcde
# 1-3 b: cdefg
# 2-9 c: ccccccccc
# ```
#
# Each line gives the password policy and then the password. The password policy indicates the lowest and highest number of times a given letter must appear for the password to be valid. For example, `1-3 a` means that the password must contain `a` at least `1` time and at most `3` times.
#
# In the above example, *`2`* passwords are valid. The middle password, `cdefg`, is not; it contains no instances of b, but needs at least `1`. The first and third passwords are valid: they contain one `a` or nine `c`, both within the limits of their respective policies.
#
# *How many passwords are valid* according to their policies?
#
# To begin, [get your puzzle input](https://adventofcode.com/2020/day/2/input)

# %%
# Initialize - from https://www.techcoil.com/blog/how-to-download-a-file-via-http-post-and-http-get-with-python-3-requests-library/
import os
import requests

if os.path.isfile('./input.txt'):
    print("-- Already have input, skipping download...")
else:
    print("-- No input.txt, attempting to download")
    response = requests.get('https://adventofcode.com/2020/day/2/input')
    if response.status_code == 200:
        with open('input.txt', 'a') as local_file:
            print("writing input.txt")
            local_file.write(response.content)

with open('input.txt', 'r') as inp:
    inputdata = [line.strip() for line in inp.readlines()]
# Out:
# -- Already have input, skipping download...

# %%
import re

answer = 0

for line in inputdata:
    #splitline = line.split(':',1)
    pattern = re.compile(r"""(?P<lowlimit>\d+)-(?P<highlimit>\d+)\s
        (?P<requiredchar>[a-z]):\s
        (?P<password>[a-z]+)""", re.VERBOSE)
    match = pattern.match(line)
    lowlimit = int(match.group("lowlimit"))
    highlimit = int(match.group("highlimit"))
    requiredchar = chr(ord(match.group("requiredchar")))
    password = match.group("password")
    #print("rule: {}-{} {}, password: {}".format(lowlimit, highlimit, requiredchar, password))
    occurences = password.count(requiredchar)
    if (occurences >= lowlimit and occurences <= highlimit):
        print("password {} is valid for the rule \"{}-{} {}\"".format(password, lowlimit, highlimit, requiredchar))
        answer = answer + 1
    else:
        print("password {} is invalid for the rule \"{}-{} {}\"".format(password, lowlimit, highlimit, requiredchar))
        
print("answer: there are {} valid passwords".format(answer))
# Out:
# password mhmjmzrmmlmmmmmm is invalid for the rule "15-16 m"
# password dcdddhzld is valid for the rule "5-6 d"
# password vqssdcbl is invalid for the rule "3-4 s"
# password bbhbbbqbbb is invalid for the rule "3-6 b"
# password cqqntqhqwwh is invalid for the rule "10-11 q"
# password ggkgggw is valid for the rule "4-7 g"
# password fdfffflfvn is valid for the rule "4-7 f"
# password thhrhrwhbshshsdhhhhr is invalid for the rule "11-16 h"
# password nnnnnnvnnnnn is valid for the rule "7-12 n"
# password ffxfhldh is invalid for the rule "4-5 f"
# password mmmmmmmmjmmmmmmmw is valid for the rule "9-17 m"
# password hqrfzhhh is valid for the rule "2-5 h"
# password vxxfxxjxwvnlx is valid for the rule "4-7 x"
# password dhhhhhhhdhhhrh is valid for the rule "11-13 h"
# password qqphvphfrlqqkztgslzb is valid for the rule "4-8 q"
# password htblqcbdxdzgvhszxz is invalid for the rule "3-15 x"
# password jjhnn is invalid for the rule "4-5 j"
# password bwkjllgcjrzhr is invalid for the rule "3-6 l"
# password ssmsspsss is valid for the rule "5-8 s"
# password ddhmhmvlkppkbbdxbc is valid for the rule "1-15 d"
# password ltllllllhgzlv is valid for the rule "7-8 l"
# password mtmmmvmmbmmfmmkmmmm is valid for the rule "1-15 m"
# password xrxzcxcx is invalid for the rule "1-3 x"
# password tttttdtv is valid for the rule "5-6 t"
# password xxxxs is valid for the rule "2-5 x"
# password gclqlml is invalid for the rule "5-7 l"
# password gggggggggn is valid for the rule "5-10 g"
# password xwjjfngjgjsjsr is invalid for the rule "6-9 j"
# password hbqtchkcmblppvqp is valid for the rule "2-7 b"
# password jjjjjjjjjjjjjjmjjj is valid for the rule "16-17 j"
# password wpppdlpphppp is invalid for the rule "1-5 p"
# password mspqqqqq is valid for the rule "3-7 q"
# password hkjk is valid for the rule "1-4 k"
# password llbllldzf is valid for the rule "3-6 l"
# password xxnxvxxxxlxxxkv is invalid for the rule "11-14 x"
# password zkkksmjmrzxftx is invalid for the rule "4-7 k"
# password lllwq is valid for the rule "2-4 l"
# password tbqqmmvkrsz is invalid for the rule "7-11 q"
# password gwfs is invalid for the rule "3-4 f"
# password ztszz is valid for the rule "3-5 z"
# password kkpzl is valid for the rule "2-4 k"
# password kkwckkzwskgbdc is invalid for the rule "1-2 k"
# password mxxxdxf is invalid for the rule "5-7 x"
# password pppp is invalid for the rule "1-3 p"
# password rcqrmcqmpcc is invalid for the rule "6-8 c"
# password srgvwsc is invalid for the rule "5-6 s"
# password wwwwwww is invalid for the rule "5-6 w"
# password xwwzfwr is valid for the rule "2-6 w"
# password djzzzcmz is valid for the rule "1-8 z"
# password dbwbbbbbldtbbbrbbq is valid for the rule "10-14 b"
# password wvzftvfvzkcvjdvvzcj is valid for the rule "5-15 v"
# password lrjdmjj is invalid for the rule "4-5 j"
# password qqqqqqqqqqqqqqkqqq is invalid for the rule "1-15 q"
# password vwkw is valid for the rule "1-2 w"
# password lccsfmkrnrldzbrc is valid for the rule "2-4 c"
# password rcpghlsspmvwvzmpvl is invalid for the rule "5-14 r"
# password nnnnnnnnx is valid for the rule "7-9 n"
# password wwwwwwwwwwwwwwwhwbww is valid for the rule "2-19 w"
# password rrrrrzc is invalid for the rule "6-7 r"
# password mnxmfqgklqddfww is invalid for the rule "3-15 w"
# password tsslqtsszsqsssqssss is valid for the rule "9-13 s"
# password jjjtjrb is invalid for the rule "5-6 j"
# password fffffffwfff is invalid for the rule "8-9 f"
# password nnnnnnhn is valid for the rule "5-7 n"
# password dnfdqvwngbddvbndbsf is invalid for the rule "8-17 d"
# password vvvvvvvvtvvvvt is invalid for the rule "13-14 v"
# password hsbnhhhs is invalid for the rule "2-3 h"
# password ggcgm is valid for the rule "2-4 g"
# password rvrrrrrvr is valid for the rule "2-7 r"
# password qpxchngsbhxrgqdgbqs is invalid for the rule "6-9 n"
# password kkkkkkkkd is valid for the rule "4-8 k"
# password mrvlldzv is valid for the rule "1-6 v"
# password vvwkwrbnwczwww is invalid for the rule "7-10 w"
# password kkkknkkkkpkkkdmkh is valid for the rule "10-14 k"
# password qqbwmssnssjs is invalid for the rule "9-10 s"
# password bzvdjz is invalid for the rule "5-6 z"
# password jjjjrzbrjzjmjzjsk is valid for the rule "6-13 j"
# password kkkkkrsskk is invalid for the rule "1-6 k"
# password vvvvvvwvvzvb is valid for the rule "8-10 v"
# password mmmmmmmmmdmm is valid for the rule "10-12 m"
# password kkkkkkkkjkk is valid for the rule "9-10 k"
# password pbcsbbprc is valid for the rule "2-8 b"
# password xxxxnpxxxk is valid for the rule "6-7 x"
# password llllllml is valid for the rule "3-7 l"
# password jrjzjjjcjx is valid for the rule "4-10 j"
# password gggmgg is valid for the rule "4-5 g"
# password nnnndnnxnnnnntnn is invalid for the rule "14-15 n"
# password hzqpgbhwh is invalid for the rule "4-6 h"
# password plzbkbrpscqbxl is invalid for the rule "4-6 b"
# password hptczmkkmplmw is invalid for the rule "5-13 m"
# password vjhrhrkdrrrk is invalid for the rule "7-8 r"
# password qqqq is valid for the rule "3-4 q"
# password sssnssssssmsss is valid for the rule "11-13 s"
# password xxbhkwvvxgxjh is invalid for the rule "11-13 x"
# password ftlrdz is valid for the rule "1-2 f"
# password mdslnl is valid for the rule "1-3 d"
# password xrzbqcxlvtlrsznplk is valid for the rule "2-10 r"
# password wwwwmwwtww is valid for the rule "8-10 w"
# password zbzplcvnvrr is valid for the rule "2-10 r"
# password lcccccclcccgcccccc is valid for the rule "5-16 c"
# password wwpwwbww is valid for the rule "3-7 w"
# password svsss is valid for the rule "1-4 s"
# password jjllkwnjjjgcjpg is valid for the rule "6-8 j"
# password cccbb is valid for the rule "3-5 c"
# password jpkjjqjjgqmzbjjhjljj is valid for the rule "1-14 j"
# password dwwlwwdmkww is valid for the rule "4-9 w"
# password pppppppjhqp is valid for the rule "7-8 p"
# password djmfmdddkhfqdzfdddd is valid for the rule "1-14 d"
# password zrbjhpg is invalid for the rule "2-3 r"
# password jjkj is valid for the rule "3-4 j"
# password qqqq is valid for the rule "3-4 q"
# password kkkkwk is valid for the rule "1-5 k"
# password ttzxtjtdjtmtttmtt is valid for the rule "6-13 t"
# password jxvx is valid for the rule "1-3 x"
# password fffffffffffkffffffff is invalid for the rule "11-12 f"
# password lllhlm is valid for the rule "4-5 l"
# password hnnnnnkdfrnntdhnk is valid for the rule "8-10 n"
# password gxxx is invalid for the rule "1-2 x"
# password pwwwwwwfwwww is valid for the rule "8-12 w"
# password ppnxfswpxfpbfcpnnpq is valid for the rule "1-19 p"
# password hhhphhhhhhgv is invalid for the rule "10-11 h"
# password dccbvcccccc is valid for the rule "1-10 c"
# password vvvvvvrvdvvvvvvvvvvl is invalid for the rule "7-12 v"
# password jbncfdbbbbcb is valid for the rule "2-11 b"
# password nnrn is valid for the rule "3-4 n"
# password btnfjtszszssdrsd is valid for the rule "3-12 s"
# password bznkfbb is valid for the rule "3-7 b"
# password rhprrhrrrhnzjhr is invalid for the rule "5-6 r"
# password xznnnwwmwnvfnfnlhn is valid for the rule "6-18 n"
# password smsvpcjvvgvtvkmvv is valid for the rule "6-11 v"
# password sssssssssssssc is valid for the rule "12-14 s"
# password ttttfx is invalid for the rule "5-6 t"
# password pppppnvppp is valid for the rule "7-9 p"
# password fbvfqsswshlgr is invalid for the rule "4-11 s"
# password thnnnnvnnnnnvbnn is valid for the rule "10-11 n"
# password dqnvjskcqhmrrtn is valid for the rule "2-13 r"
# password kvhkskkfrkr is invalid for the rule "10-11 k"
# password sssssssm is valid for the rule "7-8 s"
# password fddddvv is invalid for the rule "5-6 d"
# password qqmkfqvvqdqqckqrw is invalid for the rule "16-17 q"
# password lddrdgdddzddz is valid for the rule "7-13 d"
# password vvvvvvvvvqrvvvvvbnqx is valid for the rule "14-17 v"
# password ccqn is valid for the rule "1-4 c"
# password tbtrrqgtldttmktrt is invalid for the rule "14-15 t"
# password csccctccrrcwcqc is valid for the rule "8-14 c"
# password nnnbnnn is invalid for the rule "1-4 n"
# password pppppppppppppppppp is invalid for the rule "11-14 p"
# password hcrkddqddm is valid for the rule "4-6 d"
# password xbbbb is invalid for the rule "1-2 b"
# password cfwqnzbtfnt is valid for the rule "2-7 f"
# password qqqqkwqqlqqqq is valid for the rule "7-11 q"
# password gtgsgwg is valid for the rule "2-7 g"
# password wwks is invalid for the rule "3-4 w"
# password rjjstgwskhwc is valid for the rule "2-6 j"
# password wwwwsgrwwhwjvgqw is valid for the rule "8-15 w"
# password ffffhr is invalid for the rule "5-6 f"
# password kxcn is valid for the rule "1-4 n"
# password kkkrkzkkkkkrkhq is invalid for the rule "13-14 k"
# password fdtpdlbp is valid for the rule "2-4 d"
# password ggggg is valid for the rule "4-5 g"
# password skzrxxsxxhknxzxxxpnf is valid for the rule "5-8 x"
# password ddhhbxnlhfb is invalid for the rule "4-7 h"
# password wqqlqqqrgqqqwqqqqqq is valid for the rule "4-15 q"
# password jjwlnjb is valid for the rule "2-3 j"
# password kkxkknjkkkkkksk is valid for the rule "7-13 k"
# password ggmgggggggg is invalid for the rule "3-6 g"
# password bbgbbfd is valid for the rule "3-4 b"
# password jjjjwjjj is valid for the rule "5-7 j"
# password hvnhxhxxkzxzxc is valid for the rule "4-5 x"
# password rlrrwrrrc is valid for the rule "2-8 r"
# password ccgccrcccccbhccccm is valid for the rule "11-14 c"
# password vfffffffffff is invalid for the rule "1-5 f"
# password fffffffffffffffff is valid for the rule "16-17 f"
# password nwnnngppnn is valid for the rule "5-8 n"
# password mmmmmmmmmvmmm is valid for the rule "10-12 m"
# password llllllgll is valid for the rule "7-9 l"
# password vvvvvvvvvvvlvvvvv is valid for the rule "12-16 v"
# password wwwwwxvwwjwwdwwwq is valid for the rule "10-12 w"
# password cxjlkdwctx is valid for the rule "2-8 x"
# password mdddlndmsdd is invalid for the rule "10-11 d"
# password bhkfwhjls is valid for the rule "1-3 h"
# password cccpcncccc is valid for the rule "6-9 c"
# password tzxzctxhpt is valid for the rule "1-4 c"
# password mmmsmwmmmsmmcmh is valid for the rule "10-13 m"
# password kkkdkkkrb is invalid for the rule "8-9 k"
# password xkxjxx is valid for the rule "3-5 x"
# password cqmxqqqlhtqpgqsqwqqd is invalid for the rule "6-7 q"
# password ggzggggqg is valid for the rule "5-7 g"
# password ncnvzvrk is valid for the rule "2-4 n"
# password kkkkkzk is valid for the rule "6-7 k"
# password nnnjcmpgtgxqdwjz is valid for the rule "3-7 n"
# password zzzvmmmmlmq is valid for the rule "3-6 m"
# password nqqqqq is invalid for the rule "1-4 q"
# password cnnzvn is invalid for the rule "4-5 n"
# password bscfsnss is valid for the rule "4-8 s"
# password pqbtmxfbt is invalid for the rule "8-9 b"
# password shqjphgfvkrrj is invalid for the rule "4-13 h"
# password cnphjnhbtndtcn is valid for the rule "3-8 n"
# password ffkfzfffbftfffff is valid for the rule "11-12 f"
# password ppwppxspppbp is valid for the rule "6-8 p"
# password ddddnddd is invalid for the rule "4-5 d"
# password qnbhwnzxd is invalid for the rule "4-8 n"
# password csflkrvrq is invalid for the rule "3-8 r"
# password zzwtzzmzzzzzxdb is valid for the rule "7-9 z"
# password wgfffkw is invalid for the rule "4-7 f"
# password wgmxddvdwtdtknvsz is valid for the rule "3-6 d"
# password mzmwwwwzkxwwcvpwrs is valid for the rule "6-17 w"
# password bbnltzsmbbfp is valid for the rule "1-8 b"
# password tpztzz is valid for the rule "2-5 z"
# password rwtwrvwpwwwwpx is valid for the rule "6-10 w"
# password sdsssssdsxlpsss is invalid for the rule "11-15 s"
# password sssvsssssssssr is valid for the rule "12-14 s"
# password dqxfvxxxxlx is invalid for the rule "10-11 x"
# password zqzzzlzz is valid for the rule "6-7 z"
# password ftvbp is valid for the rule "1-2 t"
# password dddddddddmwdddshdd is valid for the rule "10-15 d"
# password wwwfbwwfqwzwvwthjw is valid for the rule "8-16 w"
# password xxxxxxpx is valid for the rule "6-7 x"
# password hchhhhhhmhfhp is invalid for the rule "11-13 h"
# password vmmmkmmmxvmmmt is valid for the rule "8-11 m"
# password jwmpwwwdwwwwkwswdwz is invalid for the rule "12-18 w"
# password hwfftvxmpfffff is valid for the rule "4-9 f"
# password nhchnnkpn is valid for the rule "1-5 n"
# password nlxtpcdlzdkhnmqsvqfg is valid for the rule "2-16 l"
# password rrrrr is valid for the rule "4-5 r"
# password dddddpgdrddddcdbddd is valid for the rule "14-16 d"
# password gskjzxjjz is invalid for the rule "4-5 j"
# password qsmccrpnsrrvwsk is invalid for the rule "13-15 s"
# password ffffffflfffffffff is valid for the rule "16-17 f"
# password nllcllllvnlwltll is invalid for the rule "14-15 l"
# password gxghgggdggg is invalid for the rule "3-4 g"
# password xfxxqljxxkxxx is valid for the rule "5-10 x"
# password lmzzq is valid for the rule "1-4 q"
# password xxxxxxxxxxxxxxxxt is valid for the rule "13-17 x"
# password bbbmxbbbjbbbb is valid for the rule "8-12 b"
# password glxxxxhxxxxwxjxxxxc is invalid for the rule "14-19 x"
# password ndflnddcxksdzdbwdddt is valid for the rule "6-19 d"
# password ccccccccl is valid for the rule "3-9 c"
# password zrxzbzwzzzzzfzzcz is valid for the rule "2-17 z"
# password fmmmml is valid for the rule "1-4 m"
# password lllllllllllllbllllll is invalid for the rule "9-17 l"
# password wgrnrkxrrmrprxrr is valid for the rule "7-10 r"
# password vcfff is valid for the rule "2-3 f"
# password tttttttttttwtttt is valid for the rule "12-15 t"
# password xcccccc is valid for the rule "1-7 c"
# password kftttbttchttttttttt is invalid for the rule "1-9 t"
# password cpkcwmdwxnwvjzfbj is valid for the rule "1-4 c"
# password nnnnnnnnlnnnnnnnn is valid for the rule "12-16 n"
# password qcjq is invalid for the rule "3-4 q"
# password tdttkshpmlgqstpttfcc is valid for the rule "4-6 t"
# password jjmcxlb is invalid for the rule "3-4 j"
# password qwdwwhwwjqmwwwwgqwfw is valid for the rule "3-19 w"
# password zzgzzzwzkzzb is valid for the rule "7-12 z"
# password nccccbdqwdccccd is invalid for the rule "14-15 c"
# password kkkkrv is valid for the rule "2-4 k"
# password kkkkkkkkkkkkkkrkkkk is invalid for the rule "14-15 k"
# password sspsssssssssstsssss is invalid for the rule "3-14 s"
# password tdrrrwcrrcrr is invalid for the rule "2-6 r"
# password gfgg is invalid for the rule "1-2 g"
# password zczhzkzzccmpg is valid for the rule "4-7 z"
# password ttvtscttzcxtt is valid for the rule "3-8 t"
# password svkxfrxrvqqpmxzsbk is invalid for the rule "3-7 q"
# password ppnppppppppppppppb is invalid for the rule "17-18 p"
# password brbbbbbbbbbbbbpbb is valid for the rule "15-16 b"
# password shxx is valid for the rule "2-4 x"
# password mmmmmmmmmmmmmmvm is valid for the rule "6-15 m"
# password bbbbb is invalid for the rule "3-4 b"
# password kgkmkkkjkkgkkmk is valid for the rule "8-10 k"
# password jtjlwjjjjjml is invalid for the rule "9-12 j"
# password whwdpqfwghhj is valid for the rule "3-4 w"
# password ssssssssssssg is valid for the rule "12-13 s"
# password nwdnntnnnqnnqnrbmnmn is invalid for the rule "13-19 n"
# password zzzzzzzzzzhzzzzzzl is valid for the rule "14-18 z"
# password bbbbbbbbbbhbbb is invalid for the rule "4-11 b"
# password jwxjftcjnkmlgcfgxzmj is invalid for the rule "3-19 x"
# password xxxxxxxzxmxx is valid for the rule "6-11 x"
# password vqgg is valid for the rule "2-4 g"
# password bbtbbvhpvbbm is valid for the rule "5-6 b"
# password csthttrtttt is valid for the rule "7-9 t"
# password qqqqnqgcqnqqqlqcq is valid for the rule "10-13 q"
# password jjjjjjjdjw is valid for the rule "8-10 j"
# password vrpnvvvvsvqvcvv is valid for the rule "9-10 v"
# password jqqqqqwqqqkqkqqq is valid for the rule "2-12 q"
# password zrcznzmzzwzzfs is valid for the rule "4-12 z"
# password ntnptpnvnns is valid for the rule "3-6 n"
# password ddddhddqdd is valid for the rule "5-10 d"
# password pcdsl is valid for the rule "1-4 l"
# password ddddz is valid for the rule "4-5 d"
# password kgnvtcvfvvqkvgwkvj is valid for the rule "3-10 v"
# password pdpxctpsxgpjshbxvvq is invalid for the rule "16-17 x"
# password kkkskkkkkkz is valid for the rule "2-11 k"
# password ddddm is valid for the rule "1-4 d"
# password bbqm is invalid for the rule "3-4 b"
# password bbrbbbb is valid for the rule "4-7 b"
# password hhhhhhhhhhhhhhhhbhwh is valid for the rule "18-19 h"
# password pvlxpppbppppptqbwgp is valid for the rule "8-10 p"
# password sfwgwnvghzrn is valid for the rule "1-3 w"
# password llwlln is valid for the rule "3-4 l"
# password jjjjjjjjjjjjjjbjjjjj is valid for the rule "15-19 j"
# password ddddndddd is invalid for the rule "1-7 d"
# password ccccchcdcccccc is valid for the rule "6-14 c"
# password ffxffjffhffzsffffffv is valid for the rule "12-17 f"
# password pnbglbbbrdn is invalid for the rule "5-9 b"
# password vvvvvvfwvvqgc is valid for the rule "8-9 v"
# password llklllgllzlm is valid for the rule "5-10 l"
# password tttttt is invalid for the rule "2-5 t"
# password fsfhzcfffvffnrfv is invalid for the rule "3-7 f"
# password gqqqq is valid for the rule "2-5 q"
# password ccccccj is valid for the rule "6-7 c"
# password vrgjgkggvpggggggg is valid for the rule "9-13 g"
# password nrqnnknbvntszznzmgbn is valid for the rule "4-10 n"
# password wslrxrx is valid for the rule "2-7 x"
# password ssszbwst is valid for the rule "4-6 s"
# password mzmcgnm is invalid for the rule "4-6 m"
# password gdggggggg is valid for the rule "6-8 g"
# password qqqqqknrq is valid for the rule "3-6 q"
# password dddddddddddddddzd is valid for the rule "16-17 d"
# password bbbpbbbbbbvb is valid for the rule "4-11 b"
# password jrppp is valid for the rule "3-4 p"
# password wgznngfndc is valid for the rule "2-7 n"
# password kcfrnfcpknxfgj is valid for the rule "2-9 f"
# password nvdlmzgpllqzllvlqlt is invalid for the rule "11-14 l"
# password ggggdsgg is valid for the rule "5-6 g"
# password kqflshskjhrcgrfcr is invalid for the rule "15-17 r"
# password gpfwfffffffbfffffff is valid for the rule "13-17 f"
# password srssfssshssgsstss is invalid for the rule "15-17 s"
# password fvfpfbffffb is valid for the rule "4-8 f"
# password wwwwwwwwwwwwwwwr is valid for the rule "11-16 w"
# password jhjvhwd is invalid for the rule "3-4 j"
# password rrqtrr is valid for the rule "4-5 r"
# password dkwwqwdrxrwwbxwqgww is valid for the rule "6-14 w"
# password sssgk is invalid for the rule "4-5 s"
# password ddtmxd is valid for the rule "2-4 d"
# password wwwwwwwwn is valid for the rule "8-9 w"
# password rhkgdbbzdszjmbm is valid for the rule "2-15 d"
# password jvqmhwbhfqkgzw is valid for the rule "2-7 h"
# password qtqqqfqqqqqd is valid for the rule "6-12 q"
# password gsxcggzfwgggsl is invalid for the rule "3-5 g"
# password dprmlmpwpw is valid for the rule "2-7 p"
# password mmmmmmmmmkmm is invalid for the rule "9-10 m"
# password zzzqkfzt is valid for the rule "1-4 z"
# password llgllllb is valid for the rule "2-8 l"
# password hwwcspbckppcgwb is valid for the rule "3-12 w"
# password tnsxtstsstb is invalid for the rule "2-3 s"
# password fmsm is valid for the rule "1-2 m"
# password qnqfqqqqqv is valid for the rule "6-10 q"
# password tlgxxwcxgx is invalid for the rule "5-10 x"
# password kmkknmkgkkkkbkkkkkr is valid for the rule "8-16 k"
# password nwbbfcfngbbspnxbj is valid for the rule "4-16 b"
# password mmmnmvmvjxmmdmr is valid for the rule "2-9 m"
# password fkkkjfbwfkk is valid for the rule "5-7 k"
# password tmkfjfqqjmgsjmtz is valid for the rule "2-4 m"
# password zzzzzzzzzzzqzzwzzzd is invalid for the rule "3-15 z"
# password dnnnnnxtnnnnnn is invalid for the rule "9-10 n"
# password wwwlcwzl is invalid for the rule "2-3 w"
# password mzbjvzjjvjjgrjj is invalid for the rule "9-10 j"
# password dhdd is valid for the rule "3-4 d"
# password jrcrwjr is valid for the rule "2-6 r"
# password bkvvvvvvvjvv is valid for the rule "9-10 v"
# password xnwnnx is valid for the rule "2-6 x"
# password kkkkkkkkkkkkkkkkkpk is valid for the rule "18-19 k"
# password gtjrr is invalid for the rule "3-5 j"
# password jjjjjj is valid for the rule "5-6 j"
# password kkzknk is invalid for the rule "5-6 k"
# password tttttttttbdlvtq is invalid for the rule "12-15 t"
# password ddwvz is valid for the rule "1-4 d"
# password xlfffrpf is valid for the rule "3-8 f"
# password zzdscgwbxtxrd is valid for the rule "1-2 z"
# password nsnnnlnnznnxsnnnnnd is valid for the rule "5-14 n"
# password gwslkgdgwqdbgws is invalid for the rule "9-10 g"
# password sfcgkffmfc is valid for the rule "4-6 f"
# password dmmwlqmmmmmmmmnm is valid for the rule "10-14 m"
# password nnnnnnnnvnnv is valid for the rule "8-12 n"
# password lllllllllllllvqlf is invalid for the rule "15-16 l"
# password tftpttjtnt is valid for the rule "1-10 t"
# password ljzdkxtwvbmjtff is valid for the rule "2-7 t"
# password stwwlqcbtws is valid for the rule "2-9 w"
# password hjwhhvvtpg is invalid for the rule "4-6 h"
# password vvgvv is valid for the rule "3-5 v"
# password ddhcdpdjdddhddmr is valid for the rule "8-12 d"
# password kxxllzjrdxlsxx is invalid for the rule "10-11 x"
# password fffjfrff is valid for the rule "5-6 f"
# password bbbbbbbbbbbbhbbbbbbb is invalid for the rule "17-18 b"
# password znrntdqtmrg is invalid for the rule "3-8 r"
# password srsvsmsssssssssssss is invalid for the rule "6-12 s"
# password dzfvpthfxnpnz is valid for the rule "2-13 z"
# password jjjjjjrjjcjjw is valid for the rule "7-13 j"
# password tllllllljl is invalid for the rule "9-10 l"
# password mmmmmmmmmmmmmm is valid for the rule "12-14 m"
# password llllllllqlllllllggl is invalid for the rule "17-18 l"
# password dkmqddddzdnrfckdz is valid for the rule "1-9 d"
# password gmmmmmlh is invalid for the rule "6-7 m"
# password ttttxtttttttggbt is invalid for the rule "13-15 t"
# password jmzvwkjjnjsnjkjxj is valid for the rule "6-7 j"
# password gmmnmdvfmmtmmqmmzcj is valid for the rule "1-17 m"
# password hvxsjt is invalid for the rule "3-5 l"
# password kxqczpdxfpjp is invalid for the rule "7-8 x"
# password kgkkhkdkk is invalid for the rule "2-5 k"
# password nbjvcgsvf is invalid for the rule "5-7 v"
# password cxddddnsxd is invalid for the rule "8-9 d"
# password mmqnjbtbpnmp is valid for the rule "2-3 p"
# password jmmmmwvmmhtmmmmlmm is valid for the rule "11-12 m"
# password zmmjsqfmqrnzmlmwrjm is valid for the rule "3-14 m"
# password vnnnnjn is valid for the rule "3-6 n"
# password jjjjjjjcjjjs is invalid for the rule "11-12 j"
# password rrrrrrrrrrrrrrrrrr is invalid for the rule "13-17 r"
# password bcncn is invalid for the rule "4-5 c"
# password bjftxcnzpnjrzxhxlp is valid for the rule "2-3 j"
# password tzrlxlzdxzsz is invalid for the rule "9-12 z"
# password sjtltj is invalid for the rule "3-5 j"
# password wwwwwww is valid for the rule "5-7 w"
# password ppzppcwkvwmwpscfpp is valid for the rule "5-7 p"
# password jcjjjjjjjj is valid for the rule "9-10 j"
# password mmrm is valid for the rule "3-4 m"
# password zkkktkkkkk is valid for the rule "1-10 k"
# password bpfldtnfrbdfk is invalid for the rule "5-13 d"
# password zsskw is valid for the rule "2-3 s"
# password xxxxxkxxbxjxlzx is valid for the rule "6-12 x"
# password ntgdtbtwnntjbcsfz is valid for the rule "3-9 t"
# password sndjqjjdjbfjc is invalid for the rule "6-10 j"
# password ckqtjtffctwtcp is valid for the rule "3-4 t"
# password wvhffpnngzv is valid for the rule "2-3 v"
# password tlrncrsg is invalid for the rule "7-8 r"
# password gjggkfvffg is invalid for the rule "7-10 g"
# password xpxlxxxmpr is valid for the rule "4-9 x"
# password srrrprrrr is valid for the rule "6-9 r"
# password gvvnnvhvvvvvdjjvv is valid for the rule "7-10 v"
# password psnsgsnfxlscwss is valid for the rule "4-6 s"
# password vwwpwx is valid for the rule "2-4 w"
# password bbbb is valid for the rule "2-4 b"
# password vvvvvvvvvmdvvvvv is valid for the rule "2-16 v"
# password ffkffjffff is invalid for the rule "3-5 f"
# password lqqqqjqqxn is valid for the rule "6-9 q"
# password qcvwwwhw is valid for the rule "1-5 w"
# password wwwwwwwkjz is valid for the rule "2-10 w"
# password tttttttz is valid for the rule "6-8 t"
# password xxdxxxhbxxxgcdx is invalid for the rule "13-14 x"
# password svkl is invalid for the rule "2-4 n"
# password fffffcfffffffnffw is valid for the rule "8-14 f"
# password lsnnnpnnn is valid for the rule "3-6 n"
# password lllllllblllll is valid for the rule "11-13 l"
# password sssss is valid for the rule "4-5 s"
# password zbzt is invalid for the rule "3-4 z"
# password xxxsx is valid for the rule "1-4 x"
# password wlxctcccrqccsccr is valid for the rule "8-9 c"
# password vvnvndfqq is invalid for the rule "5-8 v"
# password rrrtrc is valid for the rule "4-6 r"
# password nbbbpfbbbcbzzxbf is invalid for the rule "10-15 b"
# password sglpschlsgsqbskrd is valid for the rule "4-5 s"
# password bvfzktkkkzkkjkkwkf is invalid for the rule "13-17 k"
# password zkxxxgxxkwxvxgx is valid for the rule "1-11 x"
# password dddddddddddddgdwd is valid for the rule "15-16 d"
# password pzpprsp is invalid for the rule "2-3 p"
# password sssbssscjsshwmmszst is invalid for the rule "16-19 s"
# password stsssssssgmssp is invalid for the rule "11-13 s"
# password sssssssssgs is valid for the rule "10-11 s"
# password jjjjttkj is valid for the rule "5-8 j"
# password ssssgsssswsv is valid for the rule "9-12 s"
# password kkkkkkkkkkkkkkkwb is invalid for the rule "16-17 k"
# password bzcdgvrvqg is invalid for the rule "9-10 g"
# password nnnrn is valid for the rule "4-5 n"
# password knnrnnxnnnnjndwn is valid for the rule "4-12 n"
# password mtmspm is valid for the rule "1-3 m"
# password bbbbbbbbbbbbbbbxb is valid for the rule "16-17 b"
# password mmdmqwwbmmlxmjljmm is invalid for the rule "9-14 m"
# password wzzzzzzzzzzzzszxzvz is invalid for the rule "6-11 z"
# password qqqqrqqqq is valid for the rule "2-8 q"
# password ffhf is valid for the rule "3-4 f"
# password ttlqqthvttcttttm is valid for the rule "9-12 t"
# password zwwwwlmwwlww is valid for the rule "5-8 w"
# password zjjwzkkkjlwzvkp is invalid for the rule "5-7 z"
# password zkzgzzzxtzz is valid for the rule "7-10 z"
# password vvmvvklvvvvgv is invalid for the rule "12-13 v"
# password ttttttqttttsrttktv is valid for the rule "10-14 t"
# password llhlllzllv is valid for the rule "7-10 l"
# password blwjjmj is valid for the rule "1-4 j"
# password qpffpqskqk is invalid for the rule "8-10 k"
# password wkdjxcwwswwwwwh is valid for the rule "5-9 w"
# password bbbbbbbbbbgtjb is valid for the rule "11-13 b"
# password ccccfcbccccccccccc is valid for the rule "14-16 c"
# password lflnpwbcmld is invalid for the rule "9-11 l"
# password qqqqqqflqhtpqq is valid for the rule "8-11 q"
# password zzzzzzzzzzzmzzzzzl is valid for the rule "12-18 z"
# password xxfhxx is valid for the rule "4-5 x"
# password tfrhztxxzzqczznwzz is valid for the rule "6-16 z"
# password vlrlmlllldllq is valid for the rule "4-13 l"
# password bbwbvbbhbbbbkvnbbbb is invalid for the rule "14-15 b"
# password frxxx is valid for the rule "3-5 x"
# password ffbfffnfffjlffffff is invalid for the rule "11-13 f"
# password dkrdrgdd is invalid for the rule "5-6 d"
# password gggwglggvtkglg is valid for the rule "6-8 g"
# password sqsnpp is valid for the rule "1-5 s"
# password bxjnb is valid for the rule "2-4 b"
# password hhfr is valid for the rule "1-2 h"
# password tzbpbsbbbtbbbbbbbbbb is valid for the rule "10-19 b"
# password pkmcpm is invalid for the rule "3-4 p"
# password qqqqtqcnqxkqb is valid for the rule "1-8 q"
# password ssmssqssssssssts is valid for the rule "13-15 s"
# password qqdsqrqq is valid for the rule "4-6 q"
# password zzbzzzzpzzzzz is valid for the rule "9-13 z"
# password xlrrrgrrrcrktrrhrrrc is invalid for the rule "19-20 r"
# password qzsrqqqjxwqqhqd is invalid for the rule "9-14 q"
# password ggggggsggggggggp is valid for the rule "7-15 g"
# password wwwkq is invalid for the rule "4-5 w"
# password ghgpkphhzpmhjpwxq is invalid for the rule "7-15 h"
# password vcvvvdvvvvvvvpvvhv is invalid for the rule "15-17 v"
# password qjqbfwbj is valid for the rule "1-2 j"
# password nvcwkcndt is invalid for the rule "3-9 c"
# password cccccccccpccgkclcc is valid for the rule "14-15 c"
# password pppppp is valid for the rule "5-6 p"
# password hxtxhthhshkrmh is invalid for the rule "12-14 h"
# password wqjqzqqk is invalid for the rule "1-2 q"
# password fffffffffffffbqf is valid for the rule "14-15 f"
# password vjjjjjfh is invalid for the rule "7-8 j"
# password trzzppxpptpfp is invalid for the rule "7-12 p"
# password wwwwwwwmrwwwwwwkwwww is valid for the rule "13-18 w"
# password rfffszjfsvn is invalid for the rule "10-11 f"
# password llllllmlllllllllkl is valid for the rule "9-17 l"
# password xssssqssshsss is valid for the rule "5-12 s"
# password fxxxsxbnx is valid for the rule "2-6 x"
# password nnnnxhnn is valid for the rule "4-6 n"
# password gggggggggqg is valid for the rule "10-11 g"
# password nknsfcnnnqgnnnxsnfnj is valid for the rule "8-16 n"
# password ndnnnnnn is valid for the rule "4-7 n"
# password shqphcskmqjqvqqqq is invalid for the rule "8-9 q"
# password rrrrrjrrrrrr is invalid for the rule "9-10 r"
# password zfzzzrzzzzzzzzzzzhzz is valid for the rule "16-18 z"
# password gkgggqggggggrgg is valid for the rule "2-13 g"
# password vvvvvvvvvvvvvvvvvvv is invalid for the rule "12-18 v"
# password hssq is invalid for the rule "3-4 s"
# password kdwftsxqcnhph is invalid for the rule "6-11 h"
# password ttttttttttttttttt is valid for the rule "16-17 t"
# password fffffdffffsfffffffff is invalid for the rule "6-11 f"
# password pppppjvpppppph is valid for the rule "10-14 p"
# password bbpbbbbbbtbbbbb is valid for the rule "10-15 b"
# password nnnnnnx is valid for the rule "3-7 n"
# password rrffrsr is valid for the rule "3-5 r"
# password brrrrrrrxrrrrr is valid for the rule "10-13 r"
# password ffffkjf is invalid for the rule "6-7 f"
# password srdrrsrrfrcr is valid for the rule "3-7 r"
# password gflbcxtvknsbpjbwrk is invalid for the rule "4-9 b"
# password pttpkfppcppdznpgpp is valid for the rule "8-10 p"
# password qqqqqqqqqqqqqqtqs is valid for the rule "13-16 q"
# password rrrwr is valid for the rule "1-4 r"
# password zggggggggggg is invalid for the rule "1-2 g"
# password jjjjjjwb is invalid for the rule "7-8 j"
# password pwnrvbdzxntvgjjjltqn is invalid for the rule "18-20 t"
# password fffxffflffffff is valid for the rule "8-13 f"
# password cklkk is invalid for the rule "4-5 k"
# password mmnmmmmmmnm is invalid for the rule "10-11 m"
# password qqqqqqsqqfsqzqqqq is valid for the rule "11-16 q"
# password nnnnnnbnnc is valid for the rule "2-9 n"
# password sddnmgfkdddzdd is valid for the rule "7-11 d"
# password qfdlftk is valid for the rule "1-4 f"
# password pzpppxphphpp is valid for the rule "8-10 p"
# password mlwf is invalid for the rule "2-4 m"
# password jxhhhfztzh is invalid for the rule "6-8 h"
# password ssnnnssssstsssssd is invalid for the rule "5-8 s"
# password hlxsx is invalid for the rule "3-5 x"
# password qhhhhhhwdhph is valid for the rule "7-8 h"
# password gxdvcvw is valid for the rule "2-7 v"
# password nnnnnkhnfnnnfnnnnnn is valid for the rule "14-15 n"
# password lllllllhlnklx is valid for the rule "9-10 l"
# password jjjdjcljjjjjjjjjjhj is valid for the rule "13-18 j"
# password jkhhhhhhj is valid for the rule "1-7 h"
# password tzznzzztcbxkzvssrzzz is valid for the rule "9-19 z"
# password sswssscsstnssjssss is valid for the rule "12-18 s"
# password zzzxmzgkzspdmq is valid for the rule "4-9 z"
# password ndldddpddddddkmdd is valid for the rule "6-13 d"
# password zgqrkhxqq is invalid for the rule "8-9 q"
# password mmmgfdw is valid for the rule "3-6 m"
# password dlls is valid for the rule "1-3 l"
# password kbbbsbbdbkbqbbbbs is valid for the rule "10-11 b"
# password bbbp is valid for the rule "2-4 b"
# password xctccckq is invalid for the rule "5-6 c"
# password kkkkk is valid for the rule "3-5 k"
# password bbbbbbzbbnqbbb is invalid for the rule "12-14 b"
# password jmmhqqlqqkgqcjvqq is valid for the rule "6-8 q"
# password ggggpggggghsgg is valid for the rule "11-12 g"
# password hhhhchhhbh is valid for the rule "8-9 h"
# password zwwcfgwwwwc is invalid for the rule "10-11 w"
# password xxxxnxlxxx is valid for the rule "5-8 x"
# password fffhf is valid for the rule "1-4 f"
# password fbwfxr is valid for the rule "2-3 f"
# password vrfffd is invalid for the rule "5-6 f"
# password lrrrrrrrrrrrrfc is invalid for the rule "14-15 r"
# password tbnptvtt is invalid for the rule "7-8 t"
# password rrgrrrrrrrrljrrrrrrr is valid for the rule "16-19 r"
# password bbpsh is valid for the rule "2-4 b"
# password gmmsmmlmmbmmmmmmmgkx is valid for the rule "7-13 m"
# password ggggggggggggggrfgg is valid for the rule "16-17 g"
# password fcfmr is invalid for the rule "1-2 g"
# password lclllll is valid for the rule "5-7 l"
# password nnnccgvn is valid for the rule "3-5 n"
# password npvv is valid for the rule "1-4 v"
# password sshsxsswshss is valid for the rule "5-11 s"
# password mxxkxxxxsxpkxsxhnktx is valid for the rule "9-12 x"
# password fsff is valid for the rule "3-4 f"
# password bqzzbcbbbxbk is valid for the rule "5-11 b"
# password ssxsssv is valid for the rule "3-7 s"
# password pxppjppppppvjp is valid for the rule "6-14 p"
# password hhkch is valid for the rule "2-4 h"
# password sdshspsssqs is valid for the rule "5-7 s"
# password vwkkkkwkskjr is valid for the rule "2-8 k"
# password mmmmmmmmmmmrmmmmzm is invalid for the rule "17-18 m"
# password nwrgwwwjpwwwwpv is invalid for the rule "12-15 w"
# password ttft is valid for the rule "3-4 t"
# password kfffzffzfffk is valid for the rule "5-11 f"
# password ddhddddddddcddddd is valid for the rule "15-16 d"
# password wplpvlrcqwlblvlcqm is valid for the rule "3-10 l"
# password zpzzz is valid for the rule "2-5 z"
# password vvgvv is valid for the rule "3-5 v"
# password jbgbb is valid for the rule "3-4 b"
# password ddddddndddddddd is valid for the rule "14-15 d"
# password zszfktzrzjtzzbmn is valid for the rule "4-13 z"
# password xbbxrbbbbbb is valid for the rule "1-8 b"
# password tttftt is invalid for the rule "3-4 t"
# password ptvvvcvvvvvnvvvv is invalid for the rule "5-9 v"
# password tcnnnnln is invalid for the rule "1-2 n"
# password hhhhhh is valid for the rule "5-6 h"
# password jvjjhfjbxjj is invalid for the rule "10-11 j"
# password twtdttttttttt is invalid for the rule "4-7 t"
# password zzzzzzzzzwzzzwzzzzzz is invalid for the rule "12-16 z"
# password hnhcvlnxglxlldlfgvll is valid for the rule "7-18 l"
# password jjjjjj is invalid for the rule "2-5 j"
# password nrknnntn is valid for the rule "2-8 n"
# password zzzzzzzqz is valid for the rule "8-9 z"
# password zzzzr is valid for the rule "4-5 z"
# password bztttgtllwq is valid for the rule "1-9 t"
# password ckjnntmkxxcnwkqznp is invalid for the rule "8-12 n"
# password xbrvvhbbb is valid for the rule "2-4 b"
# password dddzqd is valid for the rule "1-4 d"
# password wwlwvlwpwwdwwwwqb is invalid for the rule "13-17 w"
# password lqzmlq is invalid for the rule "3-5 q"
# password bpzzzczzpzz is invalid for the rule "8-9 z"
# password nbjqmnhxwh is valid for the rule "1-6 n"
# password qqqqqqqzq is valid for the rule "6-8 q"
# password rrrrrvrrrrnrrrrrrb is invalid for the rule "16-18 r"
# password lbfdwlpzmkl is valid for the rule "3-8 l"
# password srwcwmgvzjjxj is invalid for the rule "2-3 g"
# password wwwwwwwjwwwwwwwwww is valid for the rule "8-17 w"
# password tttttttttdttttttttvf is invalid for the rule "19-20 t"
# password pwnwxxfxnkxxtzpglx is valid for the rule "1-11 x"
# password lgpglng is invalid for the rule "6-7 g"
# password llllfll is valid for the rule "5-7 l"
# password ppppppp is invalid for the rule "5-6 p"
# password xxdf is invalid for the rule "3-4 x"
# password fgkzwrrpmvmhzplsqp is invalid for the rule "4-15 l"
# password bbqjb is valid for the rule "2-4 b"
# password kbkkkwkkk is invalid for the rule "4-6 k"
# password mppzpprpp is valid for the rule "4-8 p"
# password ttfvdtwxnnfdsnxbn is invalid for the rule "14-17 n"
# password mmzmmm is valid for the rule "3-5 m"
# password kkkkndk is invalid for the rule "6-7 k"
# password hkkrln is valid for the rule "1-6 r"
# password hhhhhmhhhhhhh is invalid for the rule "4-6 h"
# password kkkkkkkkksk is valid for the rule "7-10 k"
# password fggggg is invalid for the rule "3-4 g"
# password qhgrxxhrxjjxxhxgb is valid for the rule "5-12 x"
# password lxpxxb is valid for the rule "3-5 x"
# password frffsfjff is valid for the rule "4-7 f"
# password dpddjfxdrt is valid for the rule "4-6 d"
# password fffpxfcfffdfnfzf is invalid for the rule "11-13 f"
# password rrrrwrrrrrwrrrcfrcr is valid for the rule "12-18 r"
# password kqqqqqqqqqqqqnqqqkqq is invalid for the rule "18-19 q"
# password bgbrf is invalid for the rule "3-4 b"
# password ssssssssssssssbdss is valid for the rule "15-17 s"
# password bnvlpxlctvdd is invalid for the rule "6-9 d"
# password smsss is invalid for the rule "1-2 s"
# password cpgrfdfmm is invalid for the rule "2-9 s"
# password jjjxdqjctjjtnzcjq is valid for the rule "5-12 j"
# password xqzgsrdtcvblfpmg is invalid for the rule "9-16 g"
# password qqqsqqqqwdqqmqqpqh is valid for the rule "11-15 q"
# password xddzddtdnk is valid for the rule "3-8 d"
# password blppgpppppppx is invalid for the rule "5-8 p"
# password mqwlxbbcmqf is invalid for the rule "7-9 m"
# password ltttbttsbtrtts is valid for the rule "6-8 t"
# password kqmfkcvkwsnddkk is invalid for the rule "12-13 k"
# password hrkwqdtckqdktgctj is invalid for the rule "16-17 t"
# password mmmm is valid for the rule "2-4 m"
# password tlflzkxlvlq is valid for the rule "2-11 l"
# password jjjjjl is valid for the rule "5-6 j"
# password wzfjxsbqznqlx is valid for the rule "2-13 x"
# password mssssfzpsh is valid for the rule "4-8 s"
# password vvxvvvllvxvvvhrvvv is valid for the rule "7-17 v"
# password qchchw is invalid for the rule "3-6 h"
# password nllnnbnrvnnnmgnzb is valid for the rule "4-10 n"
# password vvvfvvvvvvvvpvvvjv is invalid for the rule "16-17 v"
# password lpbfwlffxhlxfffkf is valid for the rule "2-14 f"
# password cfwkwnl is invalid for the rule "5-7 w"
# password nnnnnn is valid for the rule "4-6 n"
# password dcddddddddd is valid for the rule "10-11 d"
# password nvrdpnvnlxccjrd is valid for the rule "1-2 d"
# password vvjvvvvvvvvvvvhzv is invalid for the rule "15-16 v"
# password wwlpllqk is valid for the rule "3-4 l"
# password pvpp is valid for the rule "2-4 p"
# password bmbf is valid for the rule "2-3 b"
# password snpdndwgtfqjlzdmmth is valid for the rule "2-12 m"
# password rpjjjjlpsj is valid for the rule "5-8 j"
# password gdmvgsgjrhg is invalid for the rule "5-9 g"
# password pppppdspp is valid for the rule "6-7 p"
# password dktlkrkwlnd is valid for the rule "2-9 k"
# password bbxbbbbbrbbbzbbbbvb is valid for the rule "9-18 b"
# password ttqdcwdjtwtqttttbc is valid for the rule "5-9 t"
# password njdddddtddhd is valid for the rule "8-10 d"
# password fkrfrrrrrrrgr is valid for the rule "4-12 r"
# password ssskgxssbs is valid for the rule "6-7 s"
# password mtmmmkmm is valid for the rule "2-6 m"
# password hhhhjhhhhhgh is invalid for the rule "11-12 h"
# password kfqkscqnq is invalid for the rule "8-9 q"
# password sdpddmvdvdxdl is valid for the rule "6-12 d"
# password cffzgfffkfff is valid for the rule "1-8 f"
# password vvvvcnljw is valid for the rule "4-9 v"
# password wplvpp is invalid for the rule "4-5 p"
# password kxwwww is invalid for the rule "2-3 w"
# password nmmmmm is valid for the rule "3-5 m"
# password ttntttjhctkztt is invalid for the rule "2-6 t"
# password vvvvvvvvvvqvvf is valid for the rule "11-14 v"
# password zzgjqzzzzzdzzkzw is invalid for the rule "7-8 z"
# password kkkkkkkkfkkkkkk is valid for the rule "13-15 k"
# password mmmmmfmgm is valid for the rule "6-7 m"
# password fgxsdqmnmmszv is invalid for the rule "7-8 m"
# password pqppp is invalid for the rule "1-3 p"
# password sssxqstsssnfsxss is valid for the rule "8-12 s"
# password qqqfqqxqqqq is valid for the rule "7-10 q"
# password djhvxxm is valid for the rule "2-5 x"
# password bjbbbrjgbbxkbgpqd is invalid for the rule "3-5 b"
# password ccscccjccmclccccccc is valid for the rule "3-17 c"
# password djrdgddwxddxskt is invalid for the rule "8-12 d"
# password hhhhhhzhmh is valid for the rule "7-9 h"
# password jwlplsct is invalid for the rule "4-8 l"
# password qvqhqxnqqmz is invalid for the rule "6-10 q"
# password wwpwqw is valid for the rule "1-5 w"
# password pltzkcsdhphdmdxkb is valid for the rule "3-12 d"
# password kkkkkkkkx is valid for the rule "1-9 k"
# password dbddqddd is valid for the rule "2-6 d"
# password njnrjnnnnnqzn is invalid for the rule "11-13 n"
# password kkkkkk is invalid for the rule "2-4 k"
# password gggggggggggcgngg is valid for the rule "11-14 g"
# password vxqvvvvvvvxvvvbvvvdv is valid for the rule "15-19 v"
# password ssscsssssf is invalid for the rule "9-10 s"
# password mmmmfmpqmmmmml is valid for the rule "1-14 m"
# password sttqtbtjt is invalid for the rule "6-8 t"
# password vkkshkw is invalid for the rule "5-7 k"
# password xscxxxm is invalid for the rule "5-7 x"
# password pddxdddqkdddzmddpd is valid for the rule "6-12 d"
# password gtmxtcttqtttxtv is valid for the rule "2-14 t"
# password rrrrrrrrrrrrrpr is valid for the rule "7-14 r"
# password ddddfdddddddddddmd is valid for the rule "15-17 d"
# password xqxxx is valid for the rule "4-5 x"
# password wwwwwwwwwwfww is valid for the rule "11-13 w"
# password jjjjjj is valid for the rule "5-6 j"
# password mmmmmm is valid for the rule "5-6 m"
# password fbblbbgbx is invalid for the rule "1-3 b"
# password vvvvvxvrvd is valid for the rule "7-8 v"
# password ffffpwpfqfhfzxdc is valid for the rule "6-11 f"
# password mtmdkbvmjmxmmdmmgb is invalid for the rule "11-17 m"
# password nhbtsbhjhgdh is invalid for the rule "8-12 h"
# password wwwpwwdwwwd is valid for the rule "7-11 w"
# password hffrfffffffqqf is invalid for the rule "11-12 f"
# password flfcffffffffqdff is valid for the rule "12-13 f"
# password hbbv is invalid for the rule "2-3 v"
# password drdlbdhwdsddd is invalid for the rule "8-11 d"
# password swrwnbwmkxwt is invalid for the rule "6-9 w"
# password llflsllllntlll is valid for the rule "10-13 l"
# password xvvvvvtkmcvvvxh is valid for the rule "8-11 v"
# password hzhbh is valid for the rule "3-4 h"
# password bzbbbbbbbgzxbbbbbm is invalid for the rule "11-12 b"
# password lqwxqmqmjlsmfwltkzl is invalid for the rule "13-17 l"
# password mwllx is valid for the rule "1-5 l"
# password cccnccxcc is valid for the rule "7-8 c"
# password tbbsjbkprrdg is invalid for the rule "6-12 b"
# password zmpzc is invalid for the rule "3-5 z"
# password jjjltjjj is valid for the rule "5-8 j"
# password xzlzgzqhqwgz is invalid for the rule "6-11 z"
# password mmmmmm is invalid for the rule "4-5 m"
# password pqwfqh is invalid for the rule "5-6 q"
# password pppppptfhpzjtct is invalid for the rule "9-14 p"
# password wdwwwlwwdww is valid for the rule "6-10 w"
# password mmmmmsmmmmqmmwmmm is valid for the rule "14-17 m"
# password vvhpfnvv is valid for the rule "4-5 v"
# password qfqqbxqvqf is valid for the rule "1-7 q"
# password zzzzzzzzzzd is valid for the rule "6-11 z"
# password gggggfggggggg is valid for the rule "6-13 g"
# password ddpdjqdddddmd is invalid for the rule "12-13 d"
# password nnndnnnnnn is valid for the rule "8-10 n"
# password zzgdzzdvz is invalid for the rule "6-7 z"
# password vdnvnsnnnlnn is valid for the rule "6-8 n"
# password bblbl is valid for the rule "3-4 b"
# password zpfjkfr is valid for the rule "1-3 f"
# password fhtxkhwhgq is invalid for the rule "7-9 h"
# password xxdxxxpxx is valid for the rule "7-9 x"
# password vmxv is valid for the rule "2-3 v"
# password zzzzzzzzzzzzzzzzzhrz is valid for the rule "18-19 z"
# password hjlsdv is invalid for the rule "4-6 x"
# password jzxxvkhsxxck is invalid for the rule "2-3 x"
# password sfjvsjqvss is valid for the rule "1-9 s"
# password xxcmpzjjtmkswwr is invalid for the rule "8-12 j"
# password ssjtvssslwszss is valid for the rule "4-10 s"
# password rhhphhhhwwhhhgrhhh is valid for the rule "9-16 h"
# password hvhhhhhzh is valid for the rule "7-8 h"
# password mmmdqbtssvmfmmmgr is valid for the rule "7-10 m"
# password hhbhzhh is valid for the rule "5-7 h"
# password ccccqcwxcccc is valid for the rule "5-10 c"
# password bmhqqbpfrqfdkq is valid for the rule "4-6 q"
# password rcmrdrrrjlrscrrhkl is valid for the rule "7-9 r"
# password ttgz is invalid for the rule "3-4 t"
# password mgggtggggzgzcphhx is valid for the rule "8-12 g"
# password dvddfctd is invalid for the rule "6-8 d"
# password gmglf is valid for the rule "2-3 g"
# password dmqwpbhmmktcvc is invalid for the rule "1-2 m"
# password bzwzzkxqpz is invalid for the rule "6-8 z"
# password xxxxbwvxcxxcxwznw is valid for the rule "1-9 x"
# password zzzzzz is valid for the rule "3-6 z"
# password kkkkhk is valid for the rule "5-6 k"
# password zqqnrcqqqplqqndfg is invalid for the rule "12-13 q"
# password jdvxtbqblmllfbnlff is invalid for the rule "9-12 l"
# password vvkvvv is valid for the rule "3-6 v"
# password xbtzjdvp is invalid for the rule "4-7 v"
# password hhmhhhhhhnmd is valid for the rule "8-10 h"
# password ttktgqfzxrdxqf is invalid for the rule "7-8 t"
# password gggjf is invalid for the rule "4-5 g"
# password qqqqmmqqqqq is valid for the rule "6-9 q"
# password rwjwwwwwrcw is valid for the rule "1-10 w"
# password ssbbbcbbbbbbd is valid for the rule "9-13 b"
# password bggggv is invalid for the rule "2-3 g"
# password wwwwfwwxwwww is valid for the rule "6-11 w"
# password ppjppppzt is valid for the rule "5-9 p"
# password gpzzzdzzjzzpzzzz is valid for the rule "3-14 z"
# password vbbfvjz is valid for the rule "1-7 v"
# password qdwczqqq is valid for the rule "2-5 q"
# password rrrrhwtf is valid for the rule "1-5 r"
# password dddddddtdddddddd is invalid for the rule "8-14 d"
# password ppppppzlp is valid for the rule "7-8 p"
# password lbssnssss is valid for the rule "5-6 s"
# password lqnpqqqqq is valid for the rule "1-8 q"
# password rkqkkk is valid for the rule "1-4 k"
# password zgkxmkmgqzg is valid for the rule "1-9 z"
# password cbbbbbf is valid for the rule "1-5 b"
# password dctcc is valid for the rule "1-4 c"
# password sxxtl is invalid for the rule "4-5 x"
# password qmfqbfmlkkkjzhqjbxpd is valid for the rule "2-8 m"
# password lhlghlcbqgsmjhbh is invalid for the rule "8-16 h"
# password xxxxxxxxx is valid for the rule "8-9 x"
# password cvndhntlghk is invalid for the rule "10-11 l"
# password dddddddcddz is valid for the rule "8-11 d"
# password jvjpjj is valid for the rule "4-5 j"
# password bmhdpdr is valid for the rule "1-2 d"
# password jnjcjnjtd is valid for the rule "1-4 j"
# password djsvzshmxmgb is invalid for the rule "4-8 m"
# password bhpkgzksrkkqk is valid for the rule "4-10 k"
# password lllllwlvwlglxqll is invalid for the rule "4-6 l"
# password hhhhhhhhhm is valid for the rule "9-10 h"
# password qqsbq is valid for the rule "3-4 q"
# password dlllllgllllszg is valid for the rule "7-9 l"
# password lllllllllvlzl is valid for the rule "10-12 l"
# password kkkkr is valid for the rule "1-5 k"
# password wdwfkwwwwww is invalid for the rule "10-11 w"
# password rzswrffrqgdhgzm is invalid for the rule "8-10 g"
# password zzzzz is valid for the rule "3-5 z"
# password pplxppppzprpdpjpppdp is valid for the rule "8-14 p"
# password mkghrgcmhxggcpddvx is invalid for the rule "6-11 g"
# password sjwbqv is invalid for the rule "4-6 b"
# password qvpqlsqqqrnbp is invalid for the rule "1-2 q"
# password wwwwwwwwwwwwwwwwwwwg is valid for the rule "8-20 w"
# password mmmmlmmmmmfwmmm is valid for the rule "12-15 m"
# password xxxxvxsxxxxwcjxvxxx is valid for the rule "1-14 x"
# password ggdggggggggggx is valid for the rule "11-14 g"
# password xrqtf is invalid for the rule "2-5 r"
# password qqqvqcqjqjfqqxqqkqj is valid for the rule "10-12 q"
# password cvszc is invalid for the rule "3-4 c"
# password mwwwwwvwx is valid for the rule "2-7 w"
# password hrgrckfb is invalid for the rule "6-8 r"
# password ddddgxcznlnwdddd is valid for the rule "4-8 d"
# password drhvzzc is valid for the rule "1-4 c"
# password pfnjnnhpnppfnrbhz is valid for the rule "3-14 n"
# password bnnnb is valid for the rule "3-4 n"
# password hhhhhphhhhhthhgh is valid for the rule "13-15 h"
# password lfllpmknmplx is valid for the rule "3-5 l"
# password lcchctpccccccx is valid for the rule "1-12 c"
# password lznsllwlbllmllzl is valid for the rule "8-9 l"
# password wwwwqshnwkwwww is valid for the rule "7-9 w"
# password zxkknkxkrkckkr is invalid for the rule "10-12 k"
# password rdrkbkgrrrrznrr is invalid for the rule "9-12 r"
# password ggggggvgggggr is invalid for the rule "12-13 g"
# password vgxggr is valid for the rule "2-5 g"
# password cccthsc is invalid for the rule "5-6 c"
# password nptdqmfglpzdvwkspt is valid for the rule "2-3 t"
# password qqsxdqqfngqqkqq is valid for the rule "4-13 q"
# password rrrrrrrrrrrrrrrrxrf is valid for the rule "17-19 r"
# password ttttmthttttt is valid for the rule "7-11 t"
# password lllwl is valid for the rule "1-5 l"
# password xxxxxxxbxxxwxxx is invalid for the rule "8-12 x"
# password dddddbfddddcdd is valid for the rule "10-11 d"
# password lfffb is valid for the rule "3-5 f"
# password ffff is valid for the rule "1-4 f"
# password swdckstss is valid for the rule "1-9 s"
# password pbfzppbmp is invalid for the rule "7-9 p"
# password xpqssm is valid for the rule "1-2 p"
# password hlhhqdhhmhhhhhphhrh is valid for the rule "6-16 h"
# password pbbgxbhqbzvnwxxb is valid for the rule "4-5 b"
# password nrbdnnnwnnnlnn is valid for the rule "7-10 n"
# password mspcrbgfqs is valid for the rule "1-2 r"
# password rlvmtklhllrvljlllx is invalid for the rule "12-16 l"
# password mpppppprpmjs is valid for the rule "7-10 p"
# password gpggwmggggv is valid for the rule "6-7 g"
# password qqdqlqq is invalid for the rule "1-4 q"
# password xxxxxxxxtxxxxxfxxxx is valid for the rule "9-18 x"
# password hhhshh is invalid for the rule "2-4 h"
# password qllq is invalid for the rule "3-4 q"
# password ggggggggggsg is valid for the rule "5-11 g"
# password mrwbr is valid for the rule "1-4 r"
# password knhmnm is invalid for the rule "4-6 m"
# password pppppppppppppp is valid for the rule "13-14 p"
# password vvtvvvvfvztvvvxwqlg is valid for the rule "9-12 v"
# password rrrrprrrrrzrr is valid for the rule "11-13 r"
# password zzzzzzjzzzzz is valid for the rule "7-11 z"
# password ddddddddddddddddjdd is valid for the rule "17-19 d"
# password ccncdc is valid for the rule "4-5 c"
# password gxxvqx is invalid for the rule "4-6 x"
# password ggpg is valid for the rule "2-3 g"
# password blgvnmbxhpmxmb is invalid for the rule "6-11 m"
# password wvdwwfqjwqwvmfrzw is valid for the rule "2-15 w"
# password ssdw is invalid for the rule "3-4 s"
# password mmllqlcllklxcml is valid for the rule "6-7 l"
# password lllplllllllllllllnl is valid for the rule "16-17 l"
# password qtwhwz is invalid for the rule "2-4 h"
# password xvvwfvfvv is valid for the rule "5-7 v"
# password kkkkkkkkqkkk is invalid for the rule "4-10 k"
# password qzvvpf is invalid for the rule "5-6 f"
# password whhddttshzds is invalid for the rule "4-11 d"
# password qjlqqqqqpwqqgqq is valid for the rule "10-13 q"
# password nwwwdmvwwwwk is invalid for the rule "11-12 w"
# password rlljllhljl is valid for the rule "4-8 l"
# password sssssssssd is valid for the rule "7-10 s"
# password qcgrtxrfccgc is valid for the rule "2-8 c"
# password pnnngnnnvnwdnn is invalid for the rule "7-8 n"
# password cscckctxcrhgc is invalid for the rule "8-10 c"
# password ngnncrnn is invalid for the rule "1-4 n"
# password ztzqttbmtztpsnrnt is valid for the rule "6-12 t"
# password bbbbbbbbbbbb is valid for the rule "8-12 b"
# password czzzzzzz is invalid for the rule "1-4 z"
# password kktmkf is invalid for the rule "1-2 k"
# password xxxjsxxnxxxxxqxxpx is valid for the rule "10-14 x"
# password vxvvrvvvdvvvvvbv is valid for the rule "11-15 v"
# password nsslmtsdxbxfsfssswfx is valid for the rule "7-9 s"
# password lllllllllllfcltllll is invalid for the rule "12-15 l"
# password qqqqtqdqq is valid for the rule "6-7 q"
# password nnnnnnnnnnnnnnbnnnn is valid for the rule "15-19 n"
# password ssttshsks is invalid for the rule "6-8 s"
# password rrrrprrrjrlqrrsrrrrb is invalid for the rule "16-20 r"
# password qqqqqqqqqq is valid for the rule "7-10 q"
# password wcbw is invalid for the rule "3-4 w"
# password tcggrxgrgvl is invalid for the rule "5-6 g"
# password kllswlmlglps is invalid for the rule "10-12 l"
# password qkvvvvqxjktkvvvjv is invalid for the rule "4-7 v"
# password rrrrqrrrrrrrrrr is invalid for the rule "5-13 r"
# password nnnnmb is invalid for the rule "1-2 n"
# password xktqbxgkkjwlt is valid for the rule "1-8 x"
# password kskk is valid for the rule "3-4 k"
# password kkdkkkkkkkkkkkkwk is invalid for the rule "16-17 k"
# password vnnnnnnnnqjnnknnnr is valid for the rule "10-15 n"
# password mfmmgmmqmmmmmkmmmmmm is invalid for the rule "8-15 m"
# password kkkgkkkjkkk is invalid for the rule "4-8 k"
# password hhhhhhhhhhhlhhhqh is invalid for the rule "16-17 h"
# password ppprpppppp is invalid for the rule "1-4 p"
# password gbdxggmggrgw is valid for the rule "1-9 g"
# password vfffff is valid for the rule "1-5 f"
# password jzvwdmsqpdnh is valid for the rule "2-12 d"
# password wwcwgzwwwwwhwwwwww is invalid for the rule "12-13 w"
# password zzdzzlzvgzzztzzz is invalid for the rule "9-10 z"
# password ffftff is valid for the rule "4-5 f"
# password xxxxxxxrxxxxxx is valid for the rule "8-14 x"
# password kgrrvrrvrr is invalid for the rule "1-4 r"
# password zkpwxkk is invalid for the rule "3-4 w"
# password tkckkfcvxkxk is valid for the rule "2-5 k"
# password rbrrrrgrrrrkbrrr is invalid for the rule "3-9 r"
# password ttxx is invalid for the rule "3-4 t"
# password zzzzzzzzzzz is valid for the rule "8-11 z"
# password pnwhxpmxpfskq is invalid for the rule "6-10 p"
# password dddddddddddddddgdddd is invalid for the rule "1-16 d"
# password kctcccg is valid for the rule "1-7 c"
# password sqqqrqqq is invalid for the rule "1-5 q"
# password fjfffffqfkfffjffff is valid for the rule "14-16 f"
# password knvrrqvtv is valid for the rule "3-8 v"
# password ptgswlvpdnmr is valid for the rule "1-2 p"
# password vvkmnvdwk is valid for the rule "3-5 v"
# password rrrrrrrrrhlrwrrrd is valid for the rule "10-14 r"
# password xffffxjfffzfffpf is valid for the rule "2-11 f"
# password nppppppp is invalid for the rule "1-5 p"
# password xxxxxxxxxxxxxxsx is valid for the rule "15-16 x"
# password prhbmdvwcmtzpvbb is invalid for the rule "15-16 b"
# password rngdttnzqtjtcttdvbmt is invalid for the rule "11-14 t"
# password ffvldffqfqffgf is valid for the rule "8-10 f"
# password rzqrmz is valid for the rule "1-3 r"
# password tntnnnntn is invalid for the rule "7-8 n"
# password qpvlfbsgswsnwsmpz is invalid for the rule "6-14 s"
# password tvwstttttttktwt is valid for the rule "9-12 t"
# password vslqbgg is invalid for the rule "4-6 g"
# password dsdddddddrdddddhdbdd is valid for the rule "9-16 d"
# answer: there are 636 valid passwords

# %% [markdown]
# ## Part 2
#
# While it appears you validated the passwords correctly, they don't seem to be what the Official Toboggan Corporate Authentication System is expecting.
#
# The shopkeeper suddenly realizes that he just accidentally explained the password policy rules from his old job at the sled rental place down the street! The Official Toboggan Corporate Policy actually works a little differently.
#
# Each policy actually describes *two positions in the password*, where `1` means the first character, `2` means the second character, and so on. (Be careful; Toboggan Corporate Policies have no concept of "index zero"!) *Exactly one of these positions* must contain the given letter. Other occurrences of the letter are irrelevant for the purposes of policy enforcement.
#
# Given the same example list from above:
#
# - `1-3 a: abcde` is *valid:* position `1` contains `a` and position `3` does not.
# - `1-3 b: cdefg` is *invalid:* neither position `1` nor position `3` contains `b`.
# - `2-9 c: ccccccccc` is *invalid:* both position `2` and position `9` contain `c`.
#
# How many passwords are valid according to the new interpretation of the policies?

# %%
answer = 0

# write your solution here - 'inputdata' is a list of the lines
